# %% [markdown]
# <h2 style="font-family:Comic Sans MS; color:#2bb5bd">Bitcoin Price Prediction Dataset</h2>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="text-align: left;">
#     <table>
#         <tr>
#             <th><b>Attribute</b></th>
#             <th><b>Details</b></th>
#         </tr>
#         <tr>
#             <td><b>Author</b></td>
#             <td><b>Muhammad Tayyab Ali</b></td>
#         </tr>
#         <tr>
#             <td>GitHub</td>
#             <td><a href="https://github.com/TayyabAli92"><img src="https://img.shields.io/badge/GitHub-Profile-red?style=for-the-badge&logo=github" alt="GitHub"/></a></td>
#         </tr>
#         <tr>
#             <td>LinkedIn</td>
#             <td><a href="https://www.linkedin.com/in/tayyab-ali-personal-86a3582b8/"><img src="https://img.shields.io/badge/LinkedIn-Profile-red?style=for-the-badge&logo=linkedin" alt="LinkedIn"/></a></td>
#         </tr>
#         <tr>
#             <td>Twitter</td>
#             <td><a href="https://twitter.com/Tayyab_Ali92"><img src="https://img.shields.io/badge/Twitter-Profile-red?style=for-the-badge&logo=twitter" alt="Twitter"/></a></td>
#         </tr>
#         <tr>
#             <td>Facebook</td>
#             <td><a href="https://www.facebook.com/profile.php?id=61556758989955"><img src="https://img.shields.io/badge/Facebook-Profile-red?style=for-the-badge&logo=facebook" alt="Facebook"/></a></td>
#         </tr>
#         <tr>
#             <td>Gmail</td>
#             <td><a href="tayyabali.personal@gmail.com"><img src="https://img.shields.io/badge/Gmail-Contact%20Me-green?style=for-the-badge&logo=gmail" alt="Gmail"/></a></td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# <h2 style="font-family:Comic Sans MS; color:#2bb5bd">Import libraries</h2>

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2 style="font-family:Comic Sans MS; color:#2bb5bd">Load the dataset</h2>

# %%
# load the dataset
df = pd.read_csv('./data/Bitcoin Historical Data3.csv')
df.head()
# Out:
#          Date     Price      Open      High       Low     Vol. Change %
# 0  03/10/2024  69,437.1  68,360.7  69,676.4  68,250.3   37.43K    1.57%
# 1  03/09/2024  68,366.5  68,178.5  68,576.9  67,923.9   30.71K    0.29%
# 2  03/08/2024  68,172.0  66,854.4  69,904.0  66,170.7  112.67K    1.97%
# 3  03/07/2024  66,855.3  66,074.6  67,985.5  65,602.6   77.47K    1.17%
# 4  03/06/2024  66,080.4  63,794.7  67,604.9  62,848.7  117.91K    3.59%

# %% [markdown]
# <h2 style="font-family:Comic Sans MS; color:#2bb5bd">Data Analysis</h2>

# %%
df.shape
# Out:
# (4985, 7)

# %%
df.describe()
# Out:
#               Date Price  Open  High   Low   Vol. Change %
# count         4985  4985  4985  4985  4985   4979     4985
# unique        4985  4030  4023  4018  4027   4413     1546
# top     03/10/2024   0.1   0.1   0.1   0.1  1.05M    0.00%
# freq             1   100   100    97   101      6      429

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4985 entries, 0 to 4984
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4985 non-null   object
#  1   Price     4985 non-null   object
#  2   Open      4985 non-null   object
#  3   High      4985 non-null   object
#  4   Low       4985 non-null   object
#  5   Vol.      4979 non-null   object
#  6   Change %  4985 non-null   object
# dtypes: object(7)
# memory usage: 272.7+ KB

# %%
df.isnull().sum()
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        6
# Change %    0
# dtype: int64

# %% [markdown]
# <h2 style="font-family:Comic Sans MS; color:#2bb5bd">Data clean</h2>

# %%
df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Change %'], dtype='object')

# %%
df.fillna(method='ffill',inplace=True)
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_5884\4116506308.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Price"] = df["Price"].str.replace(',','').astype('float64')
df["Open"] = df["Open"].str.replace(',','').astype('float64')
df["High"] = df["High"].str.replace(',','').astype('float64')
df["Low"] = df["Low"].str.replace(',','').astype('float64')

# %%
df["Vol."] = df["Vol."].str.replace('K', 'e3').str.replace('M', 'e6').str.replace('B', 'e9').astype('float64')
df["Change %"] = df["Change %"].str.replace('%','').astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4985 entries, 0 to 4984
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4985 non-null   datetime64[ns]
#  1   Price     4985 non-null   float64
#  2   Open      4985 non-null   float64
#  3   High      4985 non-null   float64
#  4   Low       4985 non-null   float64
#  5   Vol.      4985 non-null   float64
#  6   Change %  4985 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 272.7 KB

# %%
df.describe()
# Out:
#                                 Date         Price          Open  \
# count                           4985   4985.000000   4985.000000
# mean   2017-05-13 23:59:59.999999744  10652.326459  10638.464574
# min              2010-07-18 00:00:00      0.100000      0.000000
# 25%              2013-12-15 00:00:00    226.100000    226.000000
# 50%              2017-05-14 00:00:00   1763.700000   1752.300000
# 75%              2020-10-11 00:00:00  14778.500000  14754.100000
# max              2024-03-10 00:00:00  69437.100000  68360.700000
# std                              NaN  15623.642066  15602.234005
#
#                High           Low          Vol.     Change %
# count   4985.000000   4985.000000  4.985000e+03  4985.000000
# mean   10902.350873  10357.971555  1.239647e+07     0.417276
# min        0.100000      0.000000  8.000000e+01   -57.210000
# 25%      231.100000    221.000000  3.165000e+04    -1.170000
# 50%     1802.800000   1665.000000  6.843000e+04     0.000000
# ...

# %%
ax=sns.lineplot(data=df, x='Date', y='Open')
ax=sns.lineplot(ax=ax, data=df, x='Date', y='Price')
plt.ylabel('Amount')
plt.title('Price Trends')
# Out:
# Text(0.5, 1.0, 'Price Trends')

# %%
ax=sns.lineplot(data=df, x='Date', y='Vol.')
plt.title('Volume of Trade')
# Out:
# Text(0.5, 1.0, 'Volume of Trade')

# %%
ax=sns.lineplot(data=df, x='Date', y='Change %')
plt.title('Percent Change')
# Out:
# Text(0.5, 1.0, 'Percent Change')

# %%
# import calendar
import datetime as dt

# %%
df['Year'] = df['Date'].dt.year

# %%
df=df.set_index('Date')

# %%
df.head()
# Out:
#               Price     Open     High      Low      Vol.  Change %  Year
# Date
# 2024-03-10  69437.1  68360.7  69676.4  68250.3   37430.0      1.57  2024
# 2024-03-09  68366.5  68178.5  68576.9  67923.9   30710.0      0.29  2024
# 2024-03-08  68172.0  66854.4  69904.0  66170.7  112670.0      1.97  2024
# 2024-03-07  66855.3  66074.6  67985.5  65602.6   77470.0      1.17  2024
# 2024-03-06  66080.4  63794.7  67604.9  62848.7  117910.0      3.59  2024

# %%
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

def plot_periodogram(ts, detrend='linear', ax=None):
    from scipy.signal import periodogram
    fs = pd.Timedelta("365D") / pd.Timedelta("1D")
    freqencies, spectrum = periodogram(
        ts,
        fs=fs,
        detrend=detrend,
        window="boxcar",
        scaling='spectrum',
    )
    if ax is None:
        _, ax = plt.subplots()
    ax.step(freqencies, spectrum, color="purple")
    ax.set_xscale("log")
    ax.set_xticks([1, 2, 4, 6, 12, 26, 52, 104])
    ax.set_xticklabels(
        [
            "Annual (1)",
            "Semiannual (2)",
            "Quarterly (4)",
            "Bimonthly (6)",
            "Monthly (12)",
            "Biweekly (26)",
            "Weekly (52)",
            "Semiweekly (104)",
        ],
        rotation=30,
    )
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    ax.set_ylabel("Variance")
    ax.set_title("Periodogram")
    return ax

# %%
plot_periodogram(df['Price'])
# Out:
# <Axes: title={'center': 'Periodogram'}, ylabel='Variance'>

# %%
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess
from sklearn.linear_model import LinearRegression

# %%
y_ = df['Price']
y_.index = pd.to_datetime(y_.index)
y_.dropna()

new_index=pd.date_range(start=y_.index.min(), end=y_.index.max(), freq='D')
y_reindex = y_.reindex(new_index,method='ffill')

y=y_reindex.asfreq('D')

fourier = CalendarFourier(freq='A', order=2)

# %%
dp = DeterministicProcess(index=y.index, 
                          constant=True, 
                          order=1, seasonal=True,
                          additional_terms=[fourier],
                          drop=True)
X = dp.in_sample()
X_fore = dp.out_of_sample(steps=90)

model = LinearRegression(fit_intercept=False)
model.fit(X, y)

y_pred = pd.Series(model.predict(X), index=X.index)
