# %% [markdown]
# # RNN (Recurent Neural Network) - LSTM (Long Short Term Memory) - GRU (Gated Recurent Unit)
#
# ## RNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN
from tensorflow.keras.models import Sequential

# %%
# Generate example data
X = np.random.rand(100, 10, 1)
y = np.random.randint(0, 2, size=(100,))

# %%
X.shape, y.shape
# Out:
# ((100, 10, 1), (100,))

# %%
# Define the model
model = Sequential([
    SimpleRNN(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X, y, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 4s 13ms/step - loss: 0.6936 - accuracy: 0.4700
# Epoch 2/10
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6894 - accuracy: 0.5400
# Epoch 3/10
# 4/4 [==============================] - 0s 39ms/step - loss: 0.6866 - accuracy: 0.5700
# Epoch 4/10
# 4/4 [==============================] - 0s 31ms/step - loss: 0.6837 - accuracy: 0.5600
# Epoch 5/10
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6816 - accuracy: 0.5700
# Epoch 6/10
# 4/4 [==============================] - 0s 29ms/step - loss: 0.6810 - accuracy: 0.5700
# Epoch 7/10
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6776 - accuracy: 0.5800
# Epoch 8/10
# 4/4 [==============================] - 0s 30ms/step - loss: 0.6761 - accuracy: 0.6000
# Epoch 9/10
# 4/4 [==============================] - 0s 25ms/step - loss: 0.6749 - accuracy: 0.5800
# Epoch 10/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6742 - accuracy: 0.5800
# 4/4 [==============================] - 1s 4ms/step - loss: 0.6754 - accuracy: 0.5900
# Test Loss: 0.6754234433174133
# Test Accuracy: 0.5899999737739563

# %% [markdown]
# # LSTM (Long Short Term Memory) is a special kind of RNN, capable of learning long-term dependencies.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))
df.head()
# Out:
#             value
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %%
# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model
model = Sequential([
    LSTM(32, input_shape=(seq_length, 1)),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 6s 14ms/step - loss: 0.4881
# Epoch 2/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3844
# Epoch 3/100
# 4/4 [==============================] - 0s 109ms/step - loss: 0.3045
# Epoch 4/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.2383
# Epoch 5/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1966
# Epoch 6/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1705
# Epoch 7/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1655
# Epoch 8/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1661
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1702
# Epoch 10/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1673
# Epoch 11/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1593
# Epoch 12/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1548
# Epoch 13/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1536
# Epoch 14/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1554
# Epoch 15/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1568
# Epoch 16/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1564
# Epoch 17/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1541
# Epoch 18/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1509
# Epoch 19/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1491
# Epoch 20/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1470
# Epoch 21/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1461
# Epoch 22/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1454
# Epoch 23/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1443
# Epoch 24/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1416
# Epoch 25/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1416
# Epoch 26/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1442
# Epoch 27/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1452
# Epoch 28/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1439
# Epoch 29/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1414
# Epoch 30/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1370
# Epoch 31/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1342
# Epoch 32/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1336
# Epoch 33/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1326
# Epoch 34/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1295
# Epoch 35/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1295
# Epoch 36/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1280
# Epoch 37/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1266
# Epoch 38/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1248
# Epoch 39/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1223
# Epoch 40/100
# 4/4 [==============================] - 0s 92ms/step - loss: 0.1204
# Epoch 41/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1178
# Epoch 42/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1146
# Epoch 43/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1112
# Epoch 44/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1082
# Epoch 45/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1057
# Epoch 46/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1031
# Epoch 47/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0994
# Epoch 48/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0973
# Epoch 49/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0926
# Epoch 50/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0924
# Epoch 51/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0898
# Epoch 52/100
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0844
# Epoch 53/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0863
# Epoch 54/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0783
# Epoch 55/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0770
# Epoch 56/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0759
# Epoch 57/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0757
# Epoch 58/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0751
# Epoch 59/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0694
# Epoch 60/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0675
# Epoch 61/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0660
# Epoch 62/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0654
# Epoch 63/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0634
# Epoch 64/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0620
# Epoch 65/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0612
# Epoch 66/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0593
# Epoch 67/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0583
# Epoch 68/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0590
# Epoch 69/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0576
# Epoch 70/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0568
# Epoch 71/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0575
# Epoch 72/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0538
# Epoch 73/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0552
# Epoch 74/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0596
# Epoch 75/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0563
# Epoch 76/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0591
# Epoch 77/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0523
# Epoch 78/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0505
# Epoch 79/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0549
# Epoch 80/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0489
# Epoch 81/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0555
# Epoch 82/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0516
# Epoch 83/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0535
# Epoch 84/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0506
# Epoch 85/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0490
# Epoch 86/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0509
# Epoch 87/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0462
# Epoch 88/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0459
# Epoch 89/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0498
# Epoch 90/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0453
# Epoch 91/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0435
# Epoch 92/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0444
# Epoch 93/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0451
# Epoch 94/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0450
# Epoch 95/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0425
# Epoch 96/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0425
# Epoch 97/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0419
# Epoch 98/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0438
# Epoch 99/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0492
# Epoch 100/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0482
# 1/1 [==============================] - 1s 1s/step - loss: 0.9825
# Test Loss: 0.9825252294540405
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# # let's build a simple RNN-based character-level text generator using a sample text. We'll use a sequence-to-sequence prediction approach to predict the next character in a sequence.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text))) # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars)) # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model
model = Sequential([
    LSTM(128, input_shape=(X.shape[1], X.shape[2])),
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50): # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=1)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 6s 40ms/step - loss: 2.9443
# Epoch 2/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.9142
# Epoch 3/100
# 5/5 [==============================] - 0s 24ms/step - loss: 2.8961
# Epoch 4/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.8733
# Epoch 5/100
# 5/5 [==============================] - 0s 29ms/step - loss: 2.8443
# Epoch 6/100
# 5/5 [==============================] - 0s 50ms/step - loss: 2.7914
# Epoch 7/100
# 5/5 [==============================] - 0s 24ms/step - loss: 2.7789
# Epoch 8/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.7437
# Epoch 9/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.7466
# Epoch 10/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.7267
# Epoch 11/100
# 5/5 [==============================] - 0s 27ms/step - loss: 2.7546
# Epoch 12/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.7377
# Epoch 13/100
# 5/5 [==============================] - 0s 25ms/step - loss: 2.7176
# Epoch 14/100
# 5/5 [==============================] - 0s 37ms/step - loss: 2.7094
# Epoch 15/100
# 5/5 [==============================] - 0s 53ms/step - loss: 2.7216
# Epoch 92/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.6632
# Epoch 93/100
# 5/5 [==============================] - 0s 50ms/step - loss: 2.6516
# Epoch 94/100
# 5/5 [==============================] - 0s 69ms/step - loss: 2.6337
# Epoch 95/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.6220
# Epoch 96/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.6172
# Epoch 97/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.6210
# Epoch 98/100
# 5/5 [==============================] - 0s 29ms/step - loss: 2.6351
# Epoch 99/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.6164
# Epoch 100/100
# 5/5 [==============================] - 0s 29ms/step - loss: 2.6011
# Seed:
# " is a simpl "
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 61ms/step

# %% [markdown]
# Here, we first convert our sample text into sequences of characters. Each sequence of characters (X) corresponds to a next character (y). The model is trained to predict y from X.
#
# After training, we take a random seed sequence and use the model to predict the next 50 characters. The output will show the initial seed and the generated text based on it.

# %% [markdown]
# # GRU (Gated Recurrent Unit) is a variation of LSTM. It has fewer parameters than LSTM, as it lacks an output gate.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, GRU  # Note the change here
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model using GRU
model = Sequential([
    GRU(32, input_shape=(seq_length, 1)),  # Note the change here
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print('Test Loss:', loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 7s 34ms/step - loss: 0.7211
# Epoch 2/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6034
# Epoch 3/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.5052
# Epoch 4/100
# 4/4 [==============================] - 1s 253ms/step - loss: 0.4153
# Epoch 5/100
# 4/4 [==============================] - 1s 176ms/step - loss: 0.3411
# Epoch 6/100
# 4/4 [==============================] - 1s 206ms/step - loss: 0.2788
# Epoch 7/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.2359
# Epoch 8/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.
# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense  # Import GRU instead of LSTM

# Sample text data
text = "hello world! this is a simple text example for rnn."
chars = sorted(list(set(text)))  # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
    seq_in = text[i:i + seq_length]
    seq_out = text[i + seq_length]
    X.append([char_to_int[char] for char in seq_in])
    y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars))  # Normalize
y = tf.keras.utils.to_categorical(y)

# Define model using GRU
model = Sequential([
    GRU(128, input_shape=(X.shape[1], X.shape[2])),  # Change LSTM to GRU here
    Dense(len(chars), activation='softmax')
])

# Compile and train
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50):  # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 101s 860ms/step - loss: 2.9467
# Epoch 2/100
# 5/5 [==============================] - 7s 1s/step - loss: 2.9158
# Epoch 3/100
# 5/5 [==============================] - 3s 491ms/step - loss: 2.8846
# Epoch 4/100
# 5/5 [==============================] - 2s 315ms/step - loss: 2.8550
# Epoch 5/100
# 5/5 [==============================] - 3s 556ms/step - loss: 2.8345
# Epoch 6/100
# 5/5 [==============================] - 2s 326ms/step - loss: 2.7905
# Epoch 7/100
# 5/5 [==============================] - 1s 332ms/step - loss: 2.7519
# Epoch 8/100
# 5/5 [==============================] - 0s 68ms/step - loss: 2.7440
# Epoch 9/100
# 5/5 [==============================] - 0s 72ms/step - loss: 2.7635
# Epoch 10/100
# 5/5 [==============================] - 0s 71ms/step - loss: 2.7441
# Epoch 11/100
# 5/5 [==============================] - 0s 52ms/step - loss: 2.7258
# Epoch 12/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.7298
# Epoch 13/100
# 5/5 [==============================] - 1s 130ms/step - loss: 2.7327
# Epoch 14/100
# 5/5 [==============================] - 1s 110ms/step - loss: 2.7304
# Epoch 15/100
# 5/5 [==============================] - 0s 86ms/step - loss: 2.7166
# Epoch 16/100
# 5/5 [==============================] - 0s 55ms/step - loss: 2.7089
# Epoch 17/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.7043
# Epoch 18/100
# 5/5 [==============================] - 0s 93ms/step - loss: 2.7039
# Epoch 19/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.7070
# Epoch 20/100
# 5/5 [==============================] - 0s 77ms/step - loss: 2.7041
# Epoch 21/100
# 5/5 [==============================] - 0s 58ms/step - loss: 2.7110
# Epoch 22/100
# 5/5 [==============================] - 0s 37ms/step - loss: 2.7110
# Epoch 23/100
# 5/5 [==============================] - 0s 54ms/step - loss: 2.7078
# Epoch 24/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.7089
# Epoch 25/100
