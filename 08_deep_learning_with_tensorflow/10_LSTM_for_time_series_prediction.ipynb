# %% [markdown]
# # LSTM for Time Series Prediction
#
# In this notebook, we will demonstrate how to use Long Short-Term Memory (LSTM) neural networks for time series prediction.
#
# This notebook, when executed, will:
#
# 1. Load and visualize the Airline Passengers dataset.
# 2. Preprocess the data by normalizing it and splitting it into training and testing sets.
# 3. Create input-output pairs for training/testing with a certain timestep.
# 4. Build an LSTM model and train it on the prepared data.
# 5. Evaluate the model by computing its RMSE on the training and testing data.
# 6. Visualize the true data vs. the model's predictions.

# %%
# Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Data Preparation
#
# First, let's load and visualize the Airline Passengers dataset.

# %%
# Load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
dataframe = pd.read_csv(url, usecols=[1], engine='python')
plt.plot(dataframe)
plt.xlabel("Months")
plt.ylabel("Passengers")
plt.title("Monthly Total Airline Passengers 1949-1960")
plt.show()

# %% [markdown]
# ## Data Preprocessing
#
# Before training an LSTM model, we need to preprocess our data. This involves scaling our data and converting it into the right shape.

# %%
# Normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataframe.values.astype('float32'))

# Split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %% [markdown]
# ## Create Dataset Matrix
# This utility function creates a dataset matrix. Given data, and choosing a certain time step, it will create input-output pairs.

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Reshape into X=t and Y=t+1, choosing a timestep of 3
look_back = 3
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## LSTM Model Building & Training

# %%
# Create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 92/92 - 5s - loss: 0.0227 - 5s/epoch - 54ms/step
# Epoch 2/100
# 92/92 - 1s - loss: 0.0085 - 505ms/epoch - 5ms/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0069 - 343ms/epoch - 4ms/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0059 - 481ms/epoch - 5ms/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0050 - 373ms/epoch - 4ms/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0045 - 315ms/epoch - 3ms/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0042 - 380ms/epoch - 4ms/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0040 - 444ms/epoch - 5ms/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0040 - 413ms/epoch - 4ms/step
# Epoch 10/100
# 92/92 - 1s - loss: 0.0039 - 785ms/epoch - 9ms/step
# Epoch 11/100
# 92/92 - 1s - loss: 0.0038 - 624ms/epoch - 7ms/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0039 - 496ms/epoch - 5ms/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0038 - 454ms/epoch - 5ms/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0037 - 445ms/epoch - 5ms/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0038 - 443ms/epoch - 5ms/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0035 - 474ms/epoch - 5ms/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0036 - 370ms/epoch - 4ms/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0039 - 301ms/epoch - 3ms/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0036 - 371ms/epoch - 4ms/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0036 - 421ms/epoch - 5ms/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0036 - 331ms/epoch - 4ms/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0037 - 337ms/epoch - 4ms/step
# Epoch 23/100
# 92/92 - 1s - loss: 0.0036 - 740ms/epoch - 8ms/step
# Epoch 24/100
# 92/92 - 1s - loss: 0.0036 - 691ms/epoch - 8ms/step
# Epoch 25/100
# 92/92 - 0s - loss: 0.0036 - 473ms/epoch - 5ms/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0035 - 464ms/epoch - 5ms/step
# Epoch 27/100
# 92/92 - 0s - loss: 0.0036 - 346ms/epoch - 4ms/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0036 - 336ms/epoch - 4ms/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.0034 - 368ms/epoch - 4ms/step
# Epoch 30/100
# 92/92 - 0s - loss: 0.0034 - 442ms/epoch - 5ms/step
# Epoch 31/100
# 92/92 - 0s - loss: 0.0034 - 469ms/epoch - 5ms/step
# Epoch 32/100
# 92/92 - 0s - loss: 0.0033 - 461ms/epoch - 5ms/step
# Epoch 33/100
# 92/92 - 1s - loss: 0.0034 - 708ms/epoch - 8ms/step
# Epoch 34/100
# 92/92 - 0s - loss: 0.0035 - 415ms/epoch - 5ms/step
# Epoch 35/100
# 92/92 - 0s - loss: 0.0034 - 375ms/epoch - 4ms/step
# Epoch 36/100
# 92/92 - 1s - loss: 0.0033 - 529ms/epoch - 6ms/step
# Epoch 37/100
# 92/92 - 0s - loss: 0.0033 - 295ms/epoch - 3ms/step
# Epoch 38/100
# 92/92 - 0s - loss: 0.0033 - 327ms/epoch - 4ms/step
# Epoch 39/100
# 92/92 - 0s - loss: 0.0033 - 256ms/epoch - 3ms/step
# Epoch 40/100
# 92/92 - 0s - loss: 0.0033 - 284ms/epoch - 3ms/step
# Epoch 41/100
# 92/92 - 0s - loss: 0.0032 - 263ms/epoch - 3ms/step
# Epoch 42/100
# 92/92 - 0s - loss: 0.0033 - 286ms/epoch - 3ms/step
# Epoch 43/100
# 92/92 - 0s - loss: 0.0033 - 368ms/epoch - 4ms/step
# Epoch 44/100
# 92/92 - 0s - loss: 0.0032 - 298ms/epoch - 3ms/step
# Epoch 45/100
# 92/92 - 0s - loss: 0.0032 - 292ms/epoch - 3ms/step
# Epoch 46/100
# 92/92 - 0s - loss: 0.0032 - 379ms/epoch - 4ms/step
# Epoch 47/100
# 92/92 - 0s - loss: 0.0033 - 272ms/epoch - 3ms/step
# Epoch 48/100
# 92/92 - 0s - loss: 0.0032 - 296ms/epoch - 3ms/step
# Epoch 49/100
# 92/92 - 0s - loss: 0.0032 - 348ms/epoch - 4ms/step
# Epoch 50/100
# 92/92 - 0s - loss: 0.0033 - 322ms/epoch - 3ms/step
# Epoch 51/100
# 92/92 - 0s - loss: 0.0031 - 282ms/epoch - 3ms/step
# Epoch 52/100
# 92/92 - 1s - loss: 0.0030 - 854ms/epoch - 9ms/step
# Epoch 53/100
# 92/92 - 1s - loss: 0.0032 - 861ms/epoch - 9ms/step
# Epoch 54/100
# 92/92 - 1s - loss: 0.0031 - 514ms/epoch - 6ms/step
# Epoch 55/100
# 92/92 - 1s - loss: 0.0031 - 806ms/epoch - 9ms/step
# Epoch 56/100
# 92/92 - 1s - loss: 0.0031 - 842ms/epoch - 9ms/step
# Epoch 57/100
# 92/92 - 1s - loss: 0.0030 - 596ms/epoch - 6ms/step
# Epoch 58/100
# 92/92 - 1s - loss: 0.0030 - 745ms/epoch - 8ms/step
# Epoch 59/100
# 92/92 - 1s - loss: 0.0031 - 768ms/epoch - 8ms/step
# Epoch 60/100
# 92/92 - 1s - loss: 0.0030 - 842ms/epoch - 9ms/step
# Epoch 61/100
# 92/92 - 0s - loss: 0.0031 - 458ms/epoch - 5ms/step
# Epoch 62/100
# 92/92 - 0s - loss: 0.0029 - 358ms/epoch - 4ms/step
# Epoch 63/100
# 92/92 - 0s - loss: 0.0029 - 410ms/epoch - 4ms/step
# Epoch 64/100
# 92/92 - 0s - loss: 0.0029 - 351ms/epoch - 4ms/step
# Epoch 65/100
# 92/92 - 0s - loss: 0.0030 - 394ms/epoch - 4ms/step
# Epoch 66/100
# 92/92 - 0s - loss: 0.0029 - 306ms/epoch - 3ms/step
# Epoch 67/100
# 92/92 - 0s - loss: 0.0028 - 310ms/epoch - 3ms/step
# Epoch 68/100
# 92/92 - 0s - loss: 0.0029 - 415ms/epoch - 5ms/step
# Epoch 69/100
# 92/92 - 0s - loss: 0.0029 - 450ms/epoch - 5ms/step
# Epoch 70/100
# 92/92 - 1s - loss: 0.0028 - 1s/epoch - 12ms/step
# Epoch 71/100
# 92/92 - 0s - loss: 0.0028 - 321ms/epoch - 3ms/step
# Epoch 72/100
# 92/92 - 0s - loss: 0.0028 - 418ms/epoch - 5ms/step
# Epoch 73/100
# 92/92 - 0s - loss: 0.0028 - 383ms/epoch - 4ms/step
# Epoch 74/100
# 92/92 - 1s - loss: 0.0028 - 589ms/epoch - 6ms/step
# Epoch 75/100
# 92/92 - 0s - loss: 0.0027 - 308ms/epoch - 3ms/step
# Epoch 76/100
# 92/92 - 0s - loss: 0.0028 - 320ms/epoch - 3ms/step
# Epoch 77/100
# 92/92 - 0s - loss: 0.0027 - 300ms/epoch - 3ms/step
# Epoch 78/100
# 92/92 - 0s - loss: 0.0026 - 468ms/epoch - 5ms/step
# Epoch 79/100
# 92/92 - 0s - loss: 0.0027 - 330ms/epoch - 4ms/step
# Epoch 80/100
# 92/92 - 0s - loss: 0.0027 - 346ms/epoch - 4ms/step
# Epoch 81/100
# 92/92 - 0s - loss: 0.0026 - 419ms/epoch - 5ms/step
# Epoch 82/100
# 92/92 - 1s - loss: 0.0026 - 526ms/epoch - 6ms/step
# Epoch 83/100
# 92/92 - 1s - loss: 0.0026 - 575ms/epoch - 6ms/step
# Epoch 84/100
# 92/92 - 0s - loss: 0.0026 - 500ms/epoch - 5ms/step
# Epoch 85/100
# 92/92 - 0s - loss: 0.0025 - 395ms/epoch - 4ms/step
# Epoch 86/100
# 92/92 - 1s - loss: 0.0024 - 622ms/epoch - 7ms/step
# Epoch 87/100
# 92/92 - 0s - loss: 0.0026 - 308ms/epoch - 3ms/step
# Epoch 88/100
# 92/92 - 0s - loss: 0.0025 - 310ms/epoch - 3ms/step
# Epoch 89/100
# 92/92 - 0s - loss: 0.0025 - 294ms/epoch - 3ms/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0026 - 290ms/epoch - 3ms/step
# Epoch 91/100
# 92/92 - 1s - loss: 0.0025 - 661ms/epoch - 7ms/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0025 - 298ms/epoch - 3ms/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0025 - 482ms/epoch - 5ms/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0023 - 315ms/epoch - 3ms/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0024 - 310ms/epoch - 3ms/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0024 - 360ms/epoch - 4ms/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0023 - 325ms/epoch - 4ms/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0023 - 346ms/epoch - 4ms/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0025 - 377ms/epoch - 4ms/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0023 - 347ms/epoch - 4ms/step

# %% [markdown]
# ## Model Evaluation

# %%
# Make predictions
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# Invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])

# Calculate root mean squared error
trainScore = np.sqrt(((trainPredict-y_train)**2).mean())
testScore = np.sqrt(((testPredict-y_test)**2).mean())
print('Train Score: %.2f RMSE' % (trainScore))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 3/3 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 15ms/step
# Train Score: 95.49 RMSE
# Test Score: 99.55 RMSE

# %% [markdown]
# ## Visualizing Predictions

# %%
# Shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# Plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset), label="True data")
plt.plot(trainPredictPlot, label="Train Predictions")
plt.plot(testPredictPlot, label="Test Predictions")
plt.xlabel("Months")
plt.ylabel("Passengers")
plt.title("LSTM's Prediction of Airline Passengers")
plt.legend()
plt.show()

# %% [markdown]
# Good Luck and Keep Learning!
