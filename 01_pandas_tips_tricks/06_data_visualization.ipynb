# %% [markdown]
# # *Data visulaization*
# #Datavize #Datavisulaization #Codanics

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import titanic data from seaborn library
df = sns.load_dataset('titanic')

# %%
df.plot(kind='scatter', x='age', y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# change color using has codes
df.plot(kind='scatter', x='age', y='fare', color='#0000FA')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby('sex')['fare'].mean().plot(kind='bar')
plt.ylabel('Average Fare')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
# seaborn plots

# bar plot using seabron on df
sns.barplot(data = df, x='survived', y='fare')
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.boxplot(data = df, x='sex', y='age', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.scatterplot(data = df, x='fare', y='age', hue='sex')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.scatterplot(data = df, x='fare', y='age', hue='class')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.scatterplot(data = df, y='fare', x='age', hue='class')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# pip install nbformat
# Out:
# Collecting nbformat
#   Using cached nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting fastjsonschema (from nbformat)
#   Using cached fastjsonschema-2.19.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting jsonschema>=2.6 (from nbformat)
#   Using cached jsonschema-4.20.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: jupyter-core in c:\users\sibtain_ali\.conda\envs\python_eda\lib\site-packages (from nbformat) (5.5.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\sibtain_ali\.conda\envs\python_eda\lib\site-packages (from nbformat) (5.14.0)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat)
#   Using cached referencing-0.32.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat)
#   Downloading rpds_py-0.15.2-cp311-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sibtain_ali\.conda\envs\python_eda\lib\site-packages (from jupyter-core->nbformat) (4.1.0)
# Requirement already satisfied: pywin32>=300 in c:\users\sibtain_ali\.conda\envs\python_eda\lib\site-packages (from jupyter-core->nbformat) (306)
# Using cached nbformat-5.9.2-py3-none-any.whl (77 kB)
# Using cached jsonschema-4.20.0-py3-none-any.whl (84 kB)
# Using cached fastjsonschema-2.19.0-py3-none-any.whl (23 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached referencing-0.32.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.15.2-cp311-none-win_amd64.whl (194 kB)
#    ---------------------------------------- 0.0/194.7 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/194.7 kB ? eta -:--:--
#    -------- ------------------------------ 41.0/194.7 kB 653.6 kB/s eta 0:00:01
#    --------------------- ---------------- 112.6/194.7 kB 819.2 kB/s eta 0:00:01
#    ----------------------------- -------- 153.6/194.7 kB 919.0 kB/s eta 0:00:01
#    ----------------------------- -------- 153.6/194.7 kB 919.0 kB/s eta 0:00:01
#    -------------------------------------  194.6/194.7 kB 841.6 kB/s eta 0:00:01
#    -------------------------------------- 194.7/194.7 kB 621.2 kB/s eta 0:00:00
# Installing collected packages: fastjsonschema, rpds-py, attrs, referencing, jsonschema-specifications, jsonschema, nbformat
# Successfully installed attrs-23.1.0 fastjsonschema-2.19.0 jsonschema-4.20.0 jsonschema-specifications-2023.12.1 nbformat-5.9.2 referencing-0.32.0 rpds-py-0.15.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# make scatter plot via plotly
import plotly.express as px

fig = px.scatter(df, x='age', y='fare', color='class')
fig.show()
# Out:
# c:\Users\Sibtain_Ali\.conda\envs\python_eda\Lib\site-packages\plotly\express\_core.py:2044: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(required_grouper, sort=False)  # skip one_group groupers

# %%
import plotly.graph_objects as go

import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

fig = go.Figure(data=[go.Surface(z=z_data.values)])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()

# %%
import plotly.express as px
df = px.data.gapminder()
px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])
