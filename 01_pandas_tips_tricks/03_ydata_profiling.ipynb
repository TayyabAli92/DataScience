# %% [markdown]
# # Autometic EDA using `ydata_profiling`

# %%
# import libraries 
import pandas as pd
import seaborn as sns
import ydata_profiling as yd

# %%
# import data from seaborn
df = sns.load_dataset('titanic')

# %%
# ydata profile report
profile = yd.ProfileReport(df)
profile.to_file(output_file='./outputs/03_ydata_titanic.html')
# Out:
# Summarize dataset:  77%|███████▋  | 17/22 [00:01<00:00, 15.69it/s, Calculate auto correlation]   c:\Users\Tayyab Ali\.conda\envs\ydata_profiling\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'Function <code object pandas_auto_compute at 0x0000017BF5AA8B40, file "c:\Users\Tayyab Ali\.conda\envs\ydata_profiling\Lib\site-packages\ydata_profiling\model\pandas\correlations_pandas.py", line 164>')
#   warnings.warn(
# Summarize dataset:  88%|████████▊ | 36/41 [00:25<00:07,  1.46s/it, Missing diagram heatmap]   c:\Users\Tayyab Ali\.conda\envs\ydata_profiling\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# c:\Users\Tayyab Ali\.conda\envs\ydata_profiling\Lib\site-packages\ydata_profiling\model\missing.py:78: UserWarning: There was an attempt to generate the Heatmap missing values diagrams, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(missing_diagrams={"Heatmap": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: '--'')
#   warnings.warn(
# Summarize dataset: 100%|██████████| 41/41 [00:26<00:00,  1.54it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:47<00:00, 47.75s/it]
# Render HTML: 100%|██████████| 1/1 [00:10<00:00, 10.73s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  5.95it/s]

# %% [markdown]
# # Do it on our Pakistan Population Dataset

# %%
df_pop = pd.read_csv("./Data/data.csv")

# %%
# ydata profile report
profile = yd.ProfileReport(df_pop)
profile.to_file(output_file='./outputs/03b_ydata_pak_poluation.html')
# Out:
# Summarize dataset:  82%|████████▏ | 23/28 [00:03<00:00, 14.15it/s, Calculate auto correlation]                  c:\Users\Tayyab Ali\.conda\envs\ydata_profiling\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'BAHAWALPUR DIVISION'')
#   warnings.warn(
# Summarize dataset: 100%|██████████| 319/319 [08:18<00:00,  1.56s/it, Completed]
# Generate report structure: 100%|██████████| 1/1 [01:04<00:00, 64.99s/it]
# Render HTML: 100%|██████████| 1/1 [01:12<00:00, 72.80s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
